# %% [markdown]
# <h1 align="center"><font size="7" >Web scraping</font></h1>

# %% [markdown]
# # Introduction
#
# In this simple project, I propose a classic way to gather the data from the web. I use a free web site of vehicle advertisements in France [**La centrale**](https://www.lacentrale.fr/) to gather the annonyme data of vehicles.
# \
# \
# **Important remark**
# \
# When I made this project, the weeb site "La Central" didn't verify proptly if there is a robot or not. In the future the website can introduce a robot verification and the below code will not woork correctely.
# \
# Actually the website ask a verification as you can see below, but the weeb scraping work very well anyway, so I think that this verification isn't efficace.
#
#
# <p style="text-align:center">
#     <a>
#     <img src="img/img2.png"  >
#     </a>
# </p>

# %% [markdown]
# # Calling the necessary libraries
# **Reminder** : you can easily install a new library in Jupyter by the command **!pip install name_of_labrary**. \
# Example: "!pip install bs4". for more information please please see the [link](https://pypi.org/project/bs4/) of bs4

# %%
################## Importing libraries #############################
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import warnings
import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# **Initialisation**

# %%
warnings.filterwarnings('ignore')
df=pd.DataFrame(columns=['page','href','model','version','price','dep','prof','warranty','year','km'])
Nb=0

# %% [markdown]
# # The loop of each page of the website
#
# #### the main loop "for i in range (1,501)"
#
# The below part is the main part of the project. The main loop change the page index each time, so it open the page 1 and 2 and soone. We can change manually the page number "1" in the link 'https://www.lacentrale.fr/listing?page=1' by the number 2 or other number.\
# I remark manually that the maximum number of pages is 500, because of that the for loop change the index "i" from 1 to 500 (see below).
# \
# \
# In this loop, the programme open the html file by **urlopen** and extract data from HTML by using [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %% [markdown]
# #### the second loop "for d in divs":
# We can remark manually that each page shows 15 or 16 vehicles. This loop extract the data from each vehicle in the same page. especially the link of each vehicle by the command href='https...
# We can find data of each vehicle page in soup2. and the rest of code will read the needed data by using **find_all** command.
# \
# \
# To know which data you must read and how you can click on the **Inspection** by the right mouse click in the needed area, see the screenshot below:

# %% [markdown]
# <img src="img/img1.png" >

# %%
for i in range (1,501): ########## Looping for each weebsite pages, the weebsite show 500 pages as maximum, 16 vehicles by page #########
    try:
        ################### Opening each page
        url=r'https://www.lacentrale.fr/listing?page='+str(i)
        userAgent = "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.86 Safari/537.36"
        req = Request(url, None, {'User-Agent': userAgent})
        html = urlopen(req).read()
        soup= BeautifulSoup(html,"html.parser")
        divs = soup.find_all("div", {"class": "searchCard__rightContainer"})
    except:
        break  ############ Break if the page didn't open  ######################
    for d in divs:
        try:
            ################# gatherig the data from each page  ###################
            href='https://www.lacentrale.fr'+d.parent.parent['href']
            model=d.h3.find_all('span', {"class": "searchCard__makeModel"})[0].text
            version=d.h3.find_all('span', {"class": "searchCard__version"})[0].text
            price=d.div.div.select('div[class^="searchCard__fieldPrice"]')[0].find_all('span')[-1].text
            dep=d.select('div[class^="searchCard__customerLocalisation"]')[0].select('div[class^="searchCard__dptCont"]')[0].text
            prof=d.select('div[class^="searchCard__customerLocalisation"]')[0].select('div[class^="cbm-txt--default searchCard__customer"]')[0].text
            warranty=d.select('div[class^="searchCard__warrantyYearMileage"]')[0].select('div[class^="searchCard__warranty"]')[0].span.text
            year=d.select('div[class^="searchCard__warrantyYearMileage"]')[0].select('div[class^="searchCard__year"]')[0].span.text
            km=d.select('div[class^="searchCard__warrantyYearMileage"]')[0].select('div[class^="searchCard__mileage"]')[0].span.text
            dic={'page':i,'href':href,'model':model,'version':version,'price':price,'dep':dep,\
                            'prof':prof,'warranty':warranty,'year':year,'km':km}
            ######################################## Open the link of each vehicle ##########################
            req2 = Request(href, None, {'User-Agent': userAgent})
            html2 = urlopen(req2).read()
            soup2= BeautifulSoup(html2,"html.parser")
            div2= soup2.find_all("div", {"class": "cbm-moduleInfos__informationList cbm-moduleInfos__information_column_break"})
            ul=div2[0].find_all('ul')
            #################### gathering data from link of each vehicle ######################
            for u in ul:
                li=u.find_all('li')
                for l in li:
                    span=l.find_all('span')
                    dic[span[0].text]=span[1].text
                    
            myli = soup2.find_all("li", {"class": "list-item"})
            for each in myli:
                strr=each.span.get_text()
                if 'Volume du coffre :' in strr or 'Longueur :'in strr :
                    strr=strr.split(':')
                    dic[strr[0]]=strr[1]
                    
            for myspan in soup2.find_all("span", {"class": "headerSection-extraContent"}):
               dic['Ref_annonce']=myspan.get_text().split('Réf. annonce : ')[1]

            for a in soup2.find_all("a", {"class": "link button-theme4"}):
                if 'équipements & options' in a.get_text():
                    dic['Nb_option']=a.get_text().split('équipements & options')[0]
            
            publication=soup2.find_all("div", {"class": "cbm-toolboxButtons"})[0].span.text.split('\n')[1]
            dic['publication']=publication
            
            ######################## Add data to the dataframe 
            df = df.append(dic,ignore_index=True)
            Nb=Nb+1
        except:pass

    print("Page",i,"/ 500 Nb vehicles",Nb)
# Out:
# Page 1 / 500 Nb vehicles 14
# Page 2 / 500 Nb vehicles 30

# %% [markdown]
# \
# \
# This programme is not very fast, it took me one hour to gather the data of 7500 vehicles with my computer.
# \
# \
# **display the dataframe data**

# %%
df
# Out:
#    page                                               href  \
# 0     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 1     1  https://www.lacentrale.fr/utilitaire-occasion-...
# 2     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 3     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 4     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 5     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 6     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 7     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 8     1  https://www.lacentrale.fr/utilitaire-occasion-...
# 9     1  https://www.lacentrale.fr/auto-occasion-annonc...
# 10    1  https://www.lacentrale.fr/auto-occasion-annonc...
# 11    1  https://www.lacentrale.fr/auto-occasion-annonc...
# 12    1  https://www.lacentrale.fr/auto-occasion-annonc...
# 13    1  https://www.lacentrale.fr/auto-occasion-annonc...
# 14    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 15    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 16    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 17    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 18    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 19    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 20    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 21    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 22    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 23    2  https://www.lacentrale.fr/utilitaire-occasion-...
# 24    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 25    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 26    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 27    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 28    2  https://www.lacentrale.fr/auto-occasion-annonc...
# 29    2  https://www.lacentrale.fr/auto-occasion-annonc...
#
#                                 model  \
# 0                     JEEP WRANGLER 4
# 1                      FORD TRANSIT 4
# 2                      AUDI E-TRON GT
# 3                    OPEL GRANDLAND X
# 4           VOLKSWAGEN GOLF SPORTSVAN
# 5                      MINI MINI 3 5P
# 6               VOLKSWAGEN POLO 6 GTI
# 7                          SEAT ARONA
# 8          CITROEN C4 CACTUS BUSINESS
# 9                   DS DS 7 CROSSBACK
# 10       PEUGEOT 5008 (2E GENERATION)
# 11            AUDI Q5 (2E GENERATION)
# 12            PORSCHE CAYENNE 3 COUPE
# 13           FIAT 500 (2E GENERATION)
# 14                       MERCEDES GLA
# 15                VOLKSWAGEN TIGUAN 2
# 16            MERCEDES CLASSE A 3 AMG
# 17                            DS DS 3
# 18    ASTON MARTIN VANQUISH 2 VOLANTE
# 19  AUDI A1 (2E GENERATION) SPORTBACK
# 20       PEUGEOT 3008 (2E GENERATION)
# 21        PEUGEOT 208 (2E GENERATION)
# 22           BMW SERIE 1 F20 5 PORTES
# 23           RENAULT KANGOO 2 EXPRESS
# 24                   RENAULT MEGANE 4
# 25        PEUGEOT 308 (3E GENERATION)
# 26                VOLKSWAGEN TIGUAN 2
# 27                MERCEDES CLASSE A 4
# 28                         BMW X1 F48
# 29                CITROEN C5 AIRCROSS
#
#                                               version      price dep  \
# 0               IV UNLIMITED 2.2 MJET 200 SAHARA AUTO   70 620 €  66
# 1                    IV P 350 L4 TREND 2.0 L TDCI 130   33 200 €  24
# 2                      93KWH GT QUATTRO RS S EXTENDED  181 330 €  92
# 3                     1.2 ECOTEC TURBO 130 INNOVATION   21 380 €  27
# 4   (2) 1.6 TDI 115 BLUEMOTION TECHNOLOGY CONNECT ...   23 420 €  55
# 5                             III 1.5 COOPER D 116 5P   11 320 €  01
# 6                             VI 2.0 TSI 200 GTI DSG6   30 480 €  28
# 7                        1.0 TGI 90 S/S XCELLENCE BV6   20 940 €  69
# 8                        (2) 1.5 BLUEHDI 100 FEEL NAV   14 250 €  76
# 9          1.5 BLUEHDI 130 7CV GRAND CHIC AUTOMATIQUE   47 490 €  92
# 10                     II (2) 1.2 PURETECH 130 S&S GT   39 980 €  44
# 11             II 2.0 TDI 190 AVUS QUATTRO S TRONIC 7   41 300 €  30
# 12                             III COUPE E-HYBRID 5PL  157 460 €  69
# 13                   II (2) 1.2 8V 69 ECO PACK LOUNGE   14 260 €  92
# 14                                    200 INSPIRATION   23 580 €  75
# 15  II 2.0 TDI 150 BLUEMOTION TECHNOLOGY CARAT EXC...   35 820 €  79
# 16                              III (2) 45 AMG 4MATIC   40 950 €  74
# 17             (2) 1.6 BLUEHDI 120 S&S SPORT CHIC BV6   18 360 €  36
# 18                   II VOLANTE 6.0 573 TOUCHTRONIC 2  194 290 €  75
# 19              II 30 TFSI 116 DESIGN LUXE S TRONIC 7   27 580 €  74
# 20                      II HYBRID4 300 11CV GT E-EAT8   41 350 €  44
# 21             II 1.2 PURETECH 75 S&S ACTIVE BUSINESS   16 880 €  42
# 22        (F20) (2) 140I XDRIVE M PERFORMANCE BVA8 5P   44 500 €  84
# 23                    II (2) EXTRA R-LINK BLUE DCI 95   18 730 €  47
# 24                     IV 1.2 TCE 100 ENERGY BUSINESS   14 700 €  47
# 25               III 1.2 PURETECH 130 S&S ACTIVE PACK   23 190 €  76
# 26  II 2.0 TDI 190 BLUEMOTION TECHNOLOGY CONFORTLI...   34 220 €  55
# 27                             IV 200 AMG LINE 7G-DCT   36 030 €  66
# 28                       (F48) XDRIVE25I M SPORT BVA8   36 460 €  77
# 29                   1.5 BLUEHDI 130 S&S BUSINESS BV6   20 170 €  35
#
#              prof           warranty  year          km  ...  \
# 0   Professionnel  Garantie 12 mois   2019   23 956 km  ...
# 1   Professionnel   Garantie 6 mois   2018   56 736 km  ...
# 2   Professionnel  Garantie 24 mois   2020   12 636 km  ...
# 3   Professionnel  Garantie 12 mois   2016   59 854 km  ...
# 4   Professionnel  Garantie 12 mois   2018   82 530 km  ...
# 5   Professionnel   Garantie 3 mois   2017  156 600 km  ...
# 6   Professionnel  Garantie 12 mois   2019   44 650 km  ...
# 7   Professionnel  Garantie 12 mois   2019   35 217 km  ...
# 8   Professionnel   Garantie 8 mois   2018  101 947 km  ...
# 9   Professionnel  Garantie 12 mois   2023   17 731 km  ...
# 10  Professionnel  Garantie 12 mois   2020   61 748 km  ...
# 11  Professionnel  Garantie 12 mois   2016  101 313 km  ...
# 12  Professionnel   Garantie 6 mois   2021   17 732 km  ...
# 13  Professionnel  Garantie 12 mois   2018   46 423 km  ...
# 14  Professionnel  Garantie 12 mois   2015   91 468 km  ...
# 15  Professionnel  Garantie 12 mois   2019   87 675 km  ...
# 16  Professionnel   Garantie 6 mois   2017   82 140 km  ...
# 17  Professionnel   Garantie 6 mois   2016  108 844 km  ...
# 18  Professionnel  Garantie 12 mois   2015   22 962 km  ...
# 19  Professionnel   Garantie 3 mois   2017   64 800 km  ...
# 20  Professionnel  Garantie 12 mois   2021   40 997 km  ...
# 21  Professionnel  Garantie 12 mois   2021   23 074 km  ...
# 22  Professionnel  Garantie 12 mois   2017   42 399 km  ...
# 23  Professionnel  Garantie 12 mois   2019   74 315 km  ...
# 24  Professionnel   Garantie 6 mois   2019  102 999 km  ...
# 25  Professionnel  Garantie 12 mois   2019   23 091 km  ...
# 26  Professionnel  Garantie 12 mois   2018   54 527 km  ...
# 27  Professionnel  Garantie 12 mois   2020   55 246 km  ...
# 28  Professionnel   Garantie 6 mois   2018   69 636 km  ...
# 29  Professionnel   Garantie 8 mois   2020  177 825 km  ...
#
#    Autonomie constructeur? :  Capacité batterie :  Voltage batterie :   \
# 0                         NaN                  NaN                 NaN
# 1                         NaN                  NaN                 NaN
# 2                      455 Km             93.4 kWh               800 V
# 3                         NaN                  NaN                 NaN
# 4                         NaN                  NaN                 NaN
# 5                         NaN                  NaN                 NaN
# 6                         NaN                  NaN                 NaN
# 7                         NaN                  NaN                 NaN
# 8                         NaN                  NaN                 NaN
# 9                         NaN                  NaN                 NaN
# 10                        NaN                  NaN                 NaN
# 11                        NaN                  NaN                 NaN
# 12                      36 Km             14.1 kWh               382 V
# 13                        NaN                  NaN                 NaN
# 14                        NaN                  NaN                 NaN
# 15                        NaN                  NaN                 NaN
# 16                        NaN                  NaN                 NaN
# 17                        NaN                  NaN                 NaN
# 18                        NaN                  NaN                 NaN
# 19                        NaN                  NaN                 NaN
# 20                      69 Km             13.2 kWh                 NaN
# 21                        NaN                  NaN                 NaN
# 22                        NaN                  NaN                 NaN
# 23                        NaN                  NaN                 NaN
# 24                        NaN                  NaN                 NaN
# 25                        NaN                  NaN                 NaN
# 26                        NaN                  NaN                 NaN
# 27                        NaN                  NaN                 NaN
# 28                        NaN                  NaN                 NaN
# 29                        NaN                  NaN                 NaN
#
#    Intensité batterie :  Conso. batterie :  Prix inclut la batterie :   \
# 0                    NaN                NaN                        NaN
# 1                    NaN                NaN                        NaN
# 2                   40 A       19 kWh/100km                        oui
# 3                    NaN                NaN                        NaN
# 4                    NaN                NaN                        NaN
# 5                    NaN                NaN                        NaN
# 6                    NaN                NaN                        NaN
# 7                    NaN                NaN                        NaN
# 8                    NaN                NaN                        NaN
# 9                    NaN                NaN                        NaN
# 10                   NaN                NaN                        NaN
# 11                   NaN                NaN                        NaN
# 12                   NaN       18 kWh/100km                        NaN
# 13                   NaN                NaN                        NaN
# 14                   NaN                NaN                        NaN
# 15                   NaN                NaN                        NaN
# 16                   NaN                NaN                        NaN
# 17                   NaN                NaN                        NaN
# 18                   NaN                NaN                        NaN
# 19                   NaN                NaN                        NaN
# 20                   NaN                NaN                        oui
# 21                   NaN                NaN                        NaN
# 22                   NaN                NaN                        NaN
# 23                   NaN                NaN                        NaN
# 24                   NaN                NaN                        NaN
# 25                   NaN                NaN                        NaN
# 26                   NaN                NaN                        NaN
# 27                   NaN                NaN                        NaN
# 28                   NaN                NaN                        NaN
# 29                   NaN                NaN                        NaN
#
#    Garantie constructeur? :       Vérifié & Garanti? :   \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                   en cours                        NaN
# 3                        NaN                   SPOTICAR
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                   SPOTICAR
# 9                   en cours                   SPOTICAR
# 10                  en cours                   SPOTICAR
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN       Fiat Autoexpert ALTA
# 14                       NaN                        NaN
# 15                       NaN            Hyundai Promise
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
# 20                       NaN                   SPOTICAR
# 21                       NaN                   SPOTICAR
# 22                       NaN                   SPOTICAR
# 23                       NaN  Occasions du Lion PREMIUM
# 24                       NaN                        NaN
# 25                       NaN                   SPOTICAR
# 26                       NaN                        NaN
# 27                       NaN                        NaN
# 28                       NaN                        NaN
# 29                       NaN                   SPOTICAR
#
#    Prime à la conversion? :  Provenance :
# 0                        NaN           NaN
# 1                        NaN           NaN
# 2                        NaN           NaN
# 3                        NaN           NaN
# 4                        NaN           NaN
# 5                        NaN           NaN
# 6                        NaN           NaN
# 7                                      NaN
# 8                        NaN           NaN
# 9                        NaN           NaN
# 10                       NaN           NaN
# 11                       NaN           NaN
# 12                       NaN       Importé
# 13                       NaN           NaN
# 14                       NaN           NaN
# 15                       NaN           NaN
# 16                       NaN           NaN
# 17                       NaN           NaN
# 18                       NaN           NaN
# 19                                     NaN
# 20                                     NaN
# 21                                     NaN
# 22                       NaN       Importé
# 23                       NaN           NaN
# 24                       NaN           NaN
# 25                                     NaN
# 26                       NaN           NaN
# 27                       NaN      Européen
# 28                       NaN           NaN
# 29                       NaN           NaN
#
# [30 rows x 46 columns]

# %% [markdown]
# **Saving the DataFrame as a csv file**

# %%
############### Save the finale file  #########################################"
file_name='lecentral_data'+datetime.datetime.now().strftime("%Y_%m_%d__%H_%M_%S")+'.csv'
df.to_csv(file_name,sep=';')

# %% [markdown]
# # Conclusion
# This is a sample way to gother data from the web.
# as you can remark the website [**La centrale**](https://www.lacentrale.fr/) alows only 500 pages,
# each page has 15 or 16 vehicles, so we can gother a total around 7500 vehicles only.
# \
# \
# But the website has more than that, as we can see the example below, the website has more than 264 000 vehicles. A way to gather the data from all vehicle, is to complete the code above with a searching by batch, each time we can define automatically the maximum and minimum price to have around 7500 vehicles. We can integrate this in a loop and inside it we can loop the 500 pages of each price batch. This idea will be explained in detail in a incomping project.

# %% [markdown]
# <img src="img/img3.png" />
#
# <p>
#     <img src="img/img3.png" width="220" height="240" >
# </p>

# %% [markdown]
# <img src="img/img1.png"  >
